# %%
dir = 'E:/thigiacmaytinh/images'

# %%
image_path = dir +'/R.jfif'
print(image_path)
# Out:
# E:/thigiacmaytinh/images/R.jfif

# %%
img01 = Image.open(image_path)

# %%
from PIL import Image

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x900>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (1600, 900)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
print("Kích thước hình ảnh: ", img01.size)
print("Định dang ảnh: ", img01.format)
# Out:
# Kích thước hình ảnh:  (1600, 900)
# Định dang ảnh:  JPEG

# %%
img01.close()
